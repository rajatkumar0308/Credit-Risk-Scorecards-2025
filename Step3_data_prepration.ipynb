# %%
import pandas as pd
import numpy as np

# -----------------------
# Step 0: Load dataset
# -----------------------
file_path = r"C:\Users\rajat\OneDrive\Desktop\Inputs scorecard\merged_customer_data.xlsx"
df = pd.read_excel(file_path, sheet_name="Sheet1")

# -----------------------
# Step 1: Clean column names (strip spaces, lower, replace special chars)
# -----------------------
df.columns = df.columns.str.strip()       # remove leading and traling spaces
df.columns = df.columns.str.replace(" ", "_")  # replace spaces with underscore
df.columns = df.columns.str.replace("-", "_")  # replace dashes with underscore
df.columns = df.columns.str.strip()       # strip again in case
print("Cleaned Columns:", df.columns.tolist())
# Out:
# Cleaned Columns: ['Customer_ID', 'Age', 'Income_INR', 'Employment_Years', 'Marital_Status', 'Education_Level', 'Credit_History_Length', 'Outstanding_Loans', 'Loan_Amount', 'Loan_Tenure_Months', 'Savings_Account_Balance', 'Checking_Account_Balance', 'Pay_History', 'Delinquency_12M', 'Credit_Card_Utilization', 'Behavior_Spending_Score', 'Behavior_Repayment_Score', 'Default_x', 'No_of_Open_Accounts', 'No_of_Closed_Accounts', 'Total_Credit_Limit', 'Total_Current_Balance', 'Credit_Utilization_Ratio', 'No_of_Inquiries_6M', 'No_of_Inquiries_12M', 'DPD_30', 'DPD_60', 'DPD_90', 'Worst_Current_Status', 'Months_Since_Most_Recent_Delinquency', 'Max_Credit_Exposure', 'Oldest_Trade_Open_Months', 'Newest_Trade_Open_Months', 'Default_y']

# %%
# -----------------------
# Step 2: Drop ID + target duplicates
# -----------------------
# Drop only if columns exist (avoids KeyError)
drop_cols = [c for c in ["Customer_ID", "Default_x"] if c in df.columns]
df = df.drop(columns=drop_cols, errors="ignore")

target = "Default_y"   # main dependent variable
independent_vars = [col for col in df.columns if col != target]

# Separate numeric vs categorical
numeric_vars = df[independent_vars].select_dtypes(include=["int64", "float64"]).columns.tolist()
categorical_vars = df[independent_vars].select_dtypes(exclude=["int64", "float64"]).columns.tolist()

# -----------------------
# Step 2 Output Preview
# -----------------------
print("\n✅ Dataset after Step 2")
print("Shape:", df.shape)
print("\nFirst 5 rows:\n", df.head())
print("\nNumeric Variables:", numeric_vars)
print("\nCategorical Variables:", categorical_vars)
# Out:
# ✅ Dataset after Step 2
# Shape: (100, 32)
#
# First 5 rows:
#     Age  Income_INR  Employment_Years Marital_Status Education_Level  \
# 0   59     2309818                 0       Divorced        Graduate
# 1   49     2431785                 8       Divorced    Postgraduate
# 2   35      488998                27         Single        Graduate
# 3   63     2043400                26         Single     High School
# 4   28     1279111                 5       Divorced        Graduate
#
#    Credit_History_Length  Outstanding_Loans  Loan_Amount  Loan_Tenure_Months  \
# 0                      5                  9       448929                  48
# 1                     12                  6       630466                  24
# 2                     16                  9       623695                  72
# 3                     16                  4       513556                  24
# 4                      7                  2       625278                  24
#
#    Savings_Account_Balance  ...  No_of_Inquiries_12M DPD_30  DPD_60  DPD_90  \
# 0                   813831  ...                    5      2       0       1
# 1                   653465  ...                    0      0       0       1
# 2                   217454  ...                    3      0       1       0
# 3                   999748  ...                    0      0       0       1
# 4                   110575  ...                    5      1       1       1
#
#    Worst_Current_Status  Months_Since_Most_Recent_Delinquency  \
# 0                     0                                    56
# 1                     0                                     6
# 2                     1                                    21
# 3                     3                                    54
# 4                     0                                    32
#
#    Max_Credit_Exposure  Oldest_Trade_Open_Months  Newest_Trade_Open_Months  \
# 0               989211                       227                        49
# 1              1626107                       237                        25
# 2               697160                       225                        40
# 3              1930947                       142                        24
# 4               339972                        87                        14
#
#    Default_y
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0
#
# [5 rows x 32 columns]
#
# Numeric Variables: ['Age', 'Income_INR', 'Employment_Years', 'Credit_History_Length', 'Outstanding_Loans', 'Loan_Amount', 'Loan_Tenure_Months', 'Savings_Account_Balance', 'Checking_Account_Balance', 'Delinquency_12M', 'Credit_Card_Utilization', 'Behavior_Spending_Score', 'Behavior_Repayment_Score', 'No_of_Open_Accounts', 'No_of_Closed_Accounts', 'Total_Credit_Limit', 'Total_Current_Balance', 'Credit_Utilization_Ratio', 'No_of_Inquiries_6M', 'No_of_Inquiries_12M', 'DPD_30', 'DPD_60', 'DPD_90', 'Worst_Current_Status', 'Months_Since_Most_Recent_Delinquency', 'Max_Credit_Exposure', 'Oldest_Trade_Open_Months', 'Newest_Trade_Open_Months']
#
# Categorical Variables: ['Marital_Status', 'Education_Level', 'Pay_History']

# %%
# -----------------------
# Helper function: Calculate WOE & IV
# -----------------------

#✅ Weight of Evidence (WOE):
# It measures how well a feature separates good (non-default) and bad (default) cases by comparing their distributions across bins. 
# Higher separation = stronger predictor.

#✅ Information Value (IV):
# It quantifies the overall predictive power of a feature for the target variable.
#IV < 0.02 → Weak, 0.02–0.1 → Medium, 0.1–0.3 → Strong, >0.3 → Very Strong.

def calc_woe_iv(data, feature, target, bins=5, categorical=False):
    tmp = data.copy()

    # Numeric → binning
    if not categorical:
        tmp[feature] = pd.qcut(tmp[feature], q=bins, duplicates='drop')

    # Group by feature bins
    grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
    grouped = grouped.rename(columns={'sum': 'bad'})
    grouped['good'] = grouped['count'] - grouped['bad']

    # Avoid divide-by-zero
    grouped = grouped[(grouped['bad'] > 0) & (grouped['good'] > 0)]

    # Distribution of good & bad
    grouped['dist_good'] = grouped['good'] / grouped['good'].sum()
    grouped['dist_bad'] = grouped['bad'] / grouped['bad'].sum()

    # WOE - it computes the distribution of good vs. bad, then calculates WOE = ln(dist_good / dist_bad)
    grouped['woe'] = np.log(grouped['dist_good'] / grouped['dist_bad'])

    # IV - Finally, it computes IV = Σ((dist_good – dist_bad) × WOE)
    grouped['iv'] = (grouped['dist_good'] - grouped['dist_bad']) * grouped['woe']
    iv = grouped['iv'].sum()

    return grouped, iv

# %%
# -----------------------
# Step 3: Compute IV for all variables
# -----------------------
iv_summary = {}  # Dictionary to store variable → IV mapping

# Numeric variables (apply binning)
for col in numeric_vars:
    _, iv = calc_woe_iv(df, col, target, bins=5, categorical=False)
    iv_summary[col] = iv

# Categorical variables (no binning)
for col in categorical_vars:
    _, iv = calc_woe_iv(df, col, target, categorical=True)
    iv_summary[col] = iv

# -----------------------
# Step 4: Rank variables by IV
# -----------------------
# Convert dictionary to DataFrame
iv_summary = pd.DataFrame(list(iv_summary.items()), columns=["Variable", "IV"])

# Sort descending (higher IV = stronger predictor)
iv_summary = iv_summary.sort_values(by="IV", ascending=False).reset_index(drop=True)

print("📊 Information Value Summary (higher = stronger predictor):")
print(iv_summary)

# -----------------------
# Step 5: IV thresholds (rule of thumb)
# -----------------------
# IV < 0.02 → Useless
# 0.02–0.1 → Weak
# 0.1–0.3 → Medium
# 0.3–0.5 → Strong
# > 0.5 → Suspicious (may be overfitting / data leakage)
# Out:
# 📊 Information Value Summary (higher = stronger predictor):
#                                 Variable        IV
# 0                        Education_Level  0.374709
# 1                Behavior_Spending_Score  0.308529
# 2                             Income_INR  0.286893
# 3                     Total_Credit_Limit  0.286893
# 4                                    Age  0.283594
# 5                     Loan_Tenure_Months  0.266022
# 6   Months_Since_Most_Recent_Delinquency  0.246311
# 7               Credit_Utilization_Ratio  0.227352
# 8                Credit_Card_Utilization  0.210313
# 9                       Employment_Years  0.193059
# 10              Behavior_Repayment_Score  0.167974
# 11                    No_of_Inquiries_6M  0.167789
# 12                 Credit_History_Length  0.161494
# 13                  Worst_Current_Status  0.157881
# 14                 No_of_Closed_Accounts  0.140442
# 15              Newest_Trade_Open_Months  0.123373
# 16              Checking_Account_Balance  0.116249
# 17                           Pay_History  0.108430
# 18                   No_of_Inquiries_12M  0.096091
# 19                       Delinquency_12M  0.095827
# 20                           Loan_Amount  0.093412
# 21                     Outstanding_Loans  0.091204
# 22              Oldest_Trade_Open_Months  0.084537
# 23                 Total_Current_Balance  0.073072
# 24                   Max_Credit_Exposure  0.045674
# 25                   No_of_Open_Accounts  0.042829
# 26                                DPD_30  0.040165
# 27               Savings_Account_Balance  0.022837
# 28                        Marital_Status  0.015263
# 29                                DPD_60  0.000000
# 30                                DPD_90  0.000000
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])
# C:\Users\rajat\AppData\Local\Temp\ipykernel_23036\1194783680.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = tmp.groupby(feature)[target].agg(['count', 'sum'])

# %%
# -----------------------
#  Missing Values / Data Quality
# -----------------------

# Count missing values per column
missing_summary = df[independent_vars].isnull().sum()
missing_summary = missing_summary[missing_summary > 0].sort_values(ascending=False)
print("\n🚨 Missing Values:\n", missing_summary)

# % of missing values
missing_pct = (df[independent_vars].isnull().mean() * 100).round(2)
print("\n% Missing by Column:\n", missing_pct[missing_pct > 0])

# 👉 Summary: This identifies columns with missing values.
# Features with too many missing values (e.g., >30%) may need imputation or removal.
# Out:
# 🚨 Missing Values:
#  Series([], dtype: int64)
#
# % Missing by Column:
#  Series([], dtype: float64)

# %%
# -------------------------------------------------------
# Multicollinearity Check using Correlation & VIF
# -------------------------------------------------------
# Summary: Correlation matrix shows pairwise relationships between numeric features.
#### A correlation matrix shows how strongly two variables are linearly related.
### Values range from -1 to +1:
### +1 → perfect positive relationship (as one increases, the other also increases).
### -1 → perfect negative relationship (as one increases, the other decreases).
### 0 → no linear relationship.


# VIF (Variance Inflation Factor) detects multicollinearity across features.
# Very high VIF means redundancy → may cause model instability.
# -------------------------------------------------------

from statsmodels.stats.outliers_influence import variance_inflation_factor  # Used to calculate VIF for numeric features

# 1. Correlation matrix of numeric features
corr_matrix = df[numeric_vars].corr()
print("🔗 Correlation Matrix:\n", corr_matrix)

# 2. Variance Inflation Factor (VIF) calculation
vif_data = pd.DataFrame()              # Create an empty DataFrame to store results
vif_data["Feature"] = numeric_vars     # Add feature names

# Calculate VIF for each feature
vif_data["VIF"] = [
    variance_inflation_factor(df[numeric_vars].dropna().values, i)
    for i in range(len(numeric_vars))
]

# Explanation:
# - For each feature index i:
#   1. Takes numeric feature data from df[numeric_vars]
#   2. Drops rows with missing values (dropna())
#   3. Converts DataFrame to NumPy array (.values)
#   4. Runs variance_inflation_factor(..., i), which:
#        • Regresses the i-th feature against all others
#        • Computes VIF = 1 / (1 - R²)

# 3. Display results sorted by highest VIF
print("\n📊 VIF Values:\n", vif_data.sort_values(by="VIF", ascending=False))
# Out:
# 🔗 Correlation Matrix:
#                                             Age  Income_INR  Employment_Years  \
# Age                                   1.000000   -0.140334          0.085102
# Income_INR                           -0.140334    1.000000         -0.210966
# Employment_Years                      0.085102   -0.210966          1.000000
# Credit_History_Length                 0.093165   -0.098896          0.077525
# Outstanding_Loans                     0.032063    0.173999         -0.023823
# Loan_Amount                          -0.157384   -0.077044          0.084214
# Loan_Tenure_Months                   -0.010025   -0.167130         -0.035460
# Savings_Account_Balance               0.093598   -0.013674         -0.007163
# Checking_Account_Balance              0.049060   -0.164939         -0.161535
# Delinquency_12M                      -0.016795    0.036355         -0.011275
# Credit_Card_Utilization              -0.031438    0.005065         -0.002664
# Behavior_Spending_Score              -0.029780   -0.120283         -0.037586
# Behavior_Repayment_Score             -0.229277    0.081298          0.094476
# No_of_Open_Accounts                  -0.109372   -0.053112          0.130531
# No_of_Closed_Accounts                -0.038406   -0.002355          0.108685
# Total_Credit_Limit                   -0.094686   -0.098888         -0.117377
# Total_Current_Balance                -0.052769    0.023118         -0.181835
# Credit_Utilization_Ratio             -0.061574    0.165304         -0.041998
# No_of_Inquiries_6M                    0.124346    0.081295         -0.197724
# No_of_Inquiries_12M                  -0.036456    0.001714         -0.051781
# DPD_30                                0.128387    0.003773         -0.187782
# DPD_60                               -0.087875   -0.049024         -0.012373
# DPD_90                                0.073120    0.036588          0.084895
# Worst_Current_Status                 -0.093912   -0.202188         -0.158584
# Months_Since_Most_Recent_Delinquency -0.148843    0.189722          0.051532
# Max_Credit_Exposure                   0.108669    0.044539         -0.095973
# Oldest_Trade_Open_Months             -0.126349    0.117143         -0.063970
# Newest_Trade_Open_Months             -0.004094    0.048253          0.152370
#
#                                       Credit_History_Length  \
# Age                                                0.093165
# Income_INR                                        -0.098896
# Employment_Years                                   0.077525
# Credit_History_Length                              1.000000
# Outstanding_Loans                                  0.062562
# Loan_Amount                                       -0.097985
# Loan_Tenure_Months                                -0.026285
# Savings_Account_Balance                            0.017781
# Checking_Account_Balance                           0.045012
# Delinquency_12M                                    0.019921
# Credit_Card_Utilization                            0.110505
# Behavior_Spending_Score                            0.113676
# Behavior_Repayment_Score                           0.073084
# No_of_Open_Accounts                               -0.150941
# No_of_Closed_Accounts                             -0.096316
# Total_Credit_Limit                                 0.029664
# Total_Current_Balance                             -0.072347
# Credit_Utilization_Ratio                          -0.062552
# No_of_Inquiries_6M                                -0.230333
# No_of_Inquiries_12M                                0.056308
# DPD_30                                            -0.031446
# DPD_60                                            -0.079920
# DPD_90                                             0.141783
# Worst_Current_Status                               0.108155
# Months_Since_Most_Recent_Delinquency               0.047756
# Max_Credit_Exposure                               -0.050759
# Oldest_Trade_Open_Months                           0.075613
# Newest_Trade_Open_Months                          -0.181577
#
#                                       Outstanding_Loans  Loan_Amount  \
# Age                                            0.032063    -0.157384
# Income_INR                                     0.173999    -0.077044
# Employment_Years                              -0.023823     0.084214
# Credit_History_Length                          0.062562    -0.097985
# Outstanding_Loans                              1.000000    -0.111856
# Loan_Amount                                   -0.111856     1.000000
# Loan_Tenure_Months                            -0.082998    -0.063573
# Savings_Account_Balance                        0.208309     0.017951
# Checking_Account_Balance                       0.070074     0.196326
# Delinquency_12M                                0.110368    -0.089153
# Credit_Card_Utilization                        0.149827    -0.169840
# Behavior_Spending_Score                       -0.034524    -0.180171
# Behavior_Repayment_Score                      -0.055327    -0.007756
# No_of_Open_Accounts                            0.074432    -0.033436
# No_of_Closed_Accounts                         -0.055981    -0.072435
# Total_Credit_Limit                             0.062767    -0.045264
# Total_Current_Balance                         -0.004573    -0.115019
# Credit_Utilization_Ratio                       0.021392     0.173960
# No_of_Inquiries_6M                             0.025269    -0.033901
# No_of_Inquiries_12M                            0.135034     0.048767
# DPD_30                                        -0.015631    -0.110745
# DPD_60                                         0.074453    -0.047341
# DPD_90                                        -0.120519     0.036389
# Worst_Current_Status                          -0.113428    -0.080057
# Months_Since_Most_Recent_Delinquency          -0.148797     0.068110
# Max_Credit_Exposure                           -0.121795    -0.210496
# Oldest_Trade_Open_Months                       0.168306    -0.021736
# Newest_Trade_Open_Months                      -0.112792    -0.004060
#
#                                       Loan_Tenure_Months  \
# Age                                            -0.010025
# Income_INR                                     -0.167130
# Employment_Years                               -0.035460
# Credit_History_Length                          -0.026285
# Outstanding_Loans                              -0.082998
# Loan_Amount                                    -0.063573
# Loan_Tenure_Months                              1.000000
# Savings_Account_Balance                        -0.121432
# Checking_Account_Balance                        0.087186
# Delinquency_12M                                 0.127527
# Credit_Card_Utilization                        -0.009933
# Behavior_Spending_Score                        -0.097250
# Behavior_Repayment_Score                        0.019793
# No_of_Open_Accounts                             0.020092
# No_of_Closed_Accounts                          -0.176025
# Total_Credit_Limit                              0.020979
# Total_Current_Balance                          -0.267612
# Credit_Utilization_Ratio                        0.061882
# No_of_Inquiries_6M                             -0.076409
# No_of_Inquiries_12M                             0.107670
# DPD_30                                         -0.132814
# DPD_60                                         -0.006717
# DPD_90                                          0.026132
# Worst_Current_Status                            0.007698
# Months_Since_Most_Recent_Delinquency            0.067517
# Max_Credit_Exposure                             0.047657
# Oldest_Trade_Open_Months                       -0.077960
# Newest_Trade_Open_Months                        0.084881
#
#                                       Savings_Account_Balance  \
# Age                                                  0.093598
# Income_INR                                          -0.013674
# Employment_Years                                    -0.007163
# Credit_History_Length                                0.017781
# Outstanding_Loans                                    0.208309
# Loan_Amount                                          0.017951
# Loan_Tenure_Months                                  -0.121432
# Savings_Account_Balance                              1.000000
# Checking_Account_Balance                             0.016213
# Delinquency_12M                                     -0.046824
# Credit_Card_Utilization                             -0.055440
# Behavior_Spending_Score                             -0.006400
# Behavior_Repayment_Score                            -0.013250
# No_of_Open_Accounts                                 -0.030409
# No_of_Closed_Accounts                               -0.044876
# Total_Credit_Limit                                   0.183978
# Total_Current_Balance                               -0.026349
# Credit_Utilization_Ratio                             0.103288
# No_of_Inquiries_6M                                   0.090351
# No_of_Inquiries_12M                                 -0.036435
# DPD_30                                               0.104062
# DPD_60                                              -0.152451
# DPD_90                                              -0.055020
# Worst_Current_Status                                 0.120108
# Months_Since_Most_Recent_Delinquency                -0.069048
# Max_Credit_Exposure                                  0.003732
# Oldest_Trade_Open_Months                             0.229542
# Newest_Trade_Open_Months                             0.043400
#
#                                       Checking_Account_Balance  \
# Age                                                   0.049060
# Income_INR                                           -0.164939
# Employment_Years                                     -0.161535
# Credit_History_Length                                 0.045012
# Outstanding_Loans                                     0.070074
# Loan_Amount                                           0.196326
# Loan_Tenure_Months                                    0.087186
# Savings_Account_Balance                               0.016213
# Checking_Account_Balance                              1.000000
# Delinquency_12M                                       0.050714
# Credit_Card_Utilization                              -0.054706
# Behavior_Spending_Score                              -0.002118
# Behavior_Repayment_Score                             -0.004725
# No_of_Open_Accounts                                   0.041207
# No_of_Closed_Accounts                                -0.105333
# Total_Credit_Limit                                    0.072134
# Total_Current_Balance                                -0.066001
# Credit_Utilization_Ratio                             -0.009486
# No_of_Inquiries_6M                                    0.080358
# No_of_Inquiries_12M                                   0.061549
# DPD_30                                                0.146894
# DPD_60                                               -0.026646
# DPD_90                                                0.114222
# Worst_Current_Status                                  0.062382
# Months_Since_Most_Recent_Delinquency                 -0.206993
# Max_Credit_Exposure                                  -0.143044
# Oldest_Trade_Open_Months                             -0.001911
# Newest_Trade_Open_Months                             -0.153063
#
#                                       Delinquency_12M  ...  \
# Age                                         -0.016795  ...
# Income_INR                                   0.036355  ...
# Employment_Years                            -0.011275  ...
# Credit_History_Length                        0.019921  ...
# Outstanding_Loans                            0.110368  ...
# Loan_Amount                                 -0.089153  ...
# Loan_Tenure_Months                           0.127527  ...
# Savings_Account_Balance                     -0.046824  ...
# Checking_Account_Balance                     0.050714  ...
# Delinquency_12M                              1.000000  ...
# Credit_Card_Utilization                      0.317686  ...
# Behavior_Spending_Score                      0.090668  ...
# Behavior_Repayment_Score                     0.009061  ...
# No_of_Open_Accounts                         -0.120018  ...
# No_of_Closed_Accounts                        0.078450  ...
# Total_Credit_Limit                          -0.000604  ...
# Total_Current_Balance                        0.071215  ...
# Credit_Utilization_Ratio                     0.093909  ...
# No_of_Inquiries_6M                           0.113465  ...
# No_of_Inquiries_12M                          0.105208  ...
# DPD_30                                      -0.118293  ...
# DPD_60                                      -0.006326  ...
# DPD_90                                      -0.010533  ...
# Worst_Current_Status                        -0.130302  ...
# Months_Since_Most_Recent_Delinquency         0.007993  ...
# Max_Credit_Exposure                         -0.116819  ...
# Oldest_Trade_Open_Months                    -0.068064  ...
# Newest_Trade_Open_Months                    -0.001501  ...
#
#                                       No_of_Inquiries_6M  No_of_Inquiries_12M  \
# Age                                             0.124346            -0.036456
# Income_INR                                      0.081295             0.001714
# Employment_Years                               -0.197724            -0.051781
# Credit_History_Length                          -0.230333             0.056308
# Outstanding_Loans                               0.025269             0.135034
# Loan_Amount                                    -0.033901             0.048767
# Loan_Tenure_Months                             -0.076409             0.107670
# Savings_Account_Balance                         0.090351            -0.036435
# Checking_Account_Balance                        0.080358             0.061549
# Delinquency_12M                                 0.113465             0.105208
# Credit_Card_Utilization                         0.093837            -0.178640
# Behavior_Spending_Score                        -0.023734             0.221722
# Behavior_Repayment_Score                       -0.213958             0.033903
# No_of_Open_Accounts                             0.106028            -0.065749
# No_of_Closed_Accounts                           0.222066            -0.006379
# Total_Credit_Limit                              0.006375             0.168995
# Total_Current_Balance                           0.011723             0.055808
# Credit_Utilization_Ratio                       -0.038400             0.224553
# No_of_Inquiries_6M                              1.000000            -0.055816
# No_of_Inquiries_12M                            -0.055816             1.000000
# DPD_30                                          0.017504            -0.100855
# DPD_60                                          0.146676            -0.060189
# DPD_90                                          0.044725            -0.223280
# Worst_Current_Status                           -0.103886            -0.097852
# Months_Since_Most_Recent_Delinquency           -0.093804            -0.046358
# Max_Credit_Exposure                            -0.058471            -0.150875
# Oldest_Trade_Open_Months                       -0.009041            -0.001469
# Newest_Trade_Open_Months                        0.091321             0.005791
#
#                                         DPD_30    DPD_60    DPD_90  \
# Age                                   0.128387 -0.087875  0.073120
# Income_INR                            0.003773 -0.049024  0.036588
# Employment_Years                     -0.187782 -0.012373  0.084895
# Credit_History_Length                -0.031446 -0.079920  0.141783
# Outstanding_Loans                    -0.015631  0.074453 -0.120519
# Loan_Amount                          -0.110745 -0.047341  0.036389
# Loan_Tenure_Months                   -0.132814 -0.006717  0.026132
# Savings_Account_Balance               0.104062 -0.152451 -0.055020
# Checking_Account_Balance              0.146894 -0.026646  0.114222
# Delinquency_12M                      -0.118293 -0.006326 -0.010533
# Credit_Card_Utilization               0.169872  0.083259  0.011636
# Behavior_Spending_Score              -0.069502 -0.035453 -0.187270
# Behavior_Repayment_Score             -0.087306 -0.165045 -0.025758
# No_of_Open_Accounts                  -0.095701 -0.045174  0.069185
# No_of_Closed_Accounts                -0.050554 -0.100697 -0.114478
# Total_Credit_Limit                    0.001929 -0.013694 -0.058270
# Total_Current_Balance                 0.049827 -0.023351 -0.048121
# Credit_Utilization_Ratio             -0.019033  0.122486  0.063347
# No_of_Inquiries_6M                    0.017504  0.146676  0.044725
# No_of_Inquiries_12M                  -0.100855 -0.060189 -0.223280
# DPD_30                                1.000000 -0.014087  0.007523
# DPD_60                               -0.014087  1.000000  0.003661
# DPD_90                                0.007523  0.003661  1.000000
# Worst_Current_Status                  0.147128  0.132771  0.092847
# Months_Since_Most_Recent_Delinquency -0.165243  0.033589  0.153744
# Max_Credit_Exposure                   0.161014  0.242300  0.174962
# Oldest_Trade_Open_Months              0.097152  0.067258 -0.053729
# Newest_Trade_Open_Months             -0.024511 -0.069006 -0.067193
#
#                                       Worst_Current_Status  \
# Age                                              -0.093912
# Income_INR                                       -0.202188
# Employment_Years                                 -0.158584
# Credit_History_Length                             0.108155
# Outstanding_Loans                                -0.113428
# Loan_Amount                                      -0.080057
# Loan_Tenure_Months                                0.007698
# Savings_Account_Balance                           0.120108
# Checking_Account_Balance                          0.062382
# Delinquency_12M                                  -0.130302
# Credit_Card_Utilization                          -0.007947
# Behavior_Spending_Score                          -0.001458
# Behavior_Repayment_Score                         -0.229480
# No_of_Open_Accounts                               0.023673
# No_of_Closed_Accounts                            -0.161385
# Total_Credit_Limit                                0.089523
# Total_Current_Balance                             0.035021
# Credit_Utilization_Ratio                          0.161538
# No_of_Inquiries_6M                               -0.103886
# No_of_Inquiries_12M                              -0.097852
# DPD_30                                            0.147128
# DPD_60                                            0.132771
# DPD_90                                            0.092847
# Worst_Current_Status                              1.000000
# Months_Since_Most_Recent_Delinquency              0.132829
# Max_Credit_Exposure                               0.174051
# Oldest_Trade_Open_Months                          0.071907
# Newest_Trade_Open_Months                         -0.025285
#
#                                       Months_Since_Most_Recent_Delinquency  \
# Age                                                              -0.148843
# Income_INR                                                        0.189722
# Employment_Years                                                  0.051532
# Credit_History_Length                                             0.047756
# Outstanding_Loans                                                -0.148797
# Loan_Amount                                                       0.068110
# Loan_Tenure_Months                                                0.067517
# Savings_Account_Balance                                          -0.069048
# Checking_Account_Balance                                         -0.206993
# Delinquency_12M                                                   0.007993
# Credit_Card_Utilization                                          -0.154236
# Behavior_Spending_Score                                          -0.009960
# Behavior_Repayment_Score                                         -0.158713
# No_of_Open_Accounts                                              -0.036970
# No_of_Closed_Accounts                                            -0.116937
# Total_Credit_Limit                                               -0.260683
# Total_Current_Balance                                            -0.032766
# Credit_Utilization_Ratio                                          0.037510
# No_of_Inquiries_6M                                               -0.093804
# No_of_Inquiries_12M                                              -0.046358
# DPD_30                                                           -0.165243
# DPD_60                                                            0.033589
# DPD_90                                                            0.153744
# Worst_Current_Status                                              0.132829
# Months_Since_Most_Recent_Delinquency                              1.000000
# Max_Credit_Exposure                                               0.076625
# Oldest_Trade_Open_Months                                          0.120653
# Newest_Trade_Open_Months                                          0.005426
#
#                                       Max_Credit_Exposure  \
# Age                                              0.108669
# Income_INR                                       0.044539
# Employment_Years                                -0.095973
# Credit_History_Length                           -0.050759
# Outstanding_Loans                               -0.121795
# Loan_Amount                                     -0.210496
# Loan_Tenure_Months                               0.047657
# Savings_Account_Balance                          0.003732
# Checking_Account_Balance                        -0.143044
# Delinquency_12M                                 -0.116819
# Credit_Card_Utilization                         -0.058331
# Behavior_Spending_Score                         -0.084822
# Behavior_Repayment_Score                        -0.111267
# No_of_Open_Accounts                             -0.108992
# No_of_Closed_Accounts                           -0.028938
# Total_Credit_Limit                              -0.044582
# Total_Current_Balance                           -0.064989
# Credit_Utilization_Ratio                         0.093056
# No_of_Inquiries_6M                              -0.058471
# No_of_Inquiries_12M                             -0.150875
# DPD_30                                           0.161014
# DPD_60                                           0.242300
# DPD_90                                           0.174962
# Worst_Current_Status                             0.174051
# Months_Since_Most_Recent_Delinquency             0.076625
# Max_Credit_Exposure                              1.000000
# Oldest_Trade_Open_Months                         0.148370
# Newest_Trade_Open_Months                        -0.113998
#
#                                       Oldest_Trade_Open_Months  \
# Age                                                  -0.126349
# Income_INR                                            0.117143
# Employment_Years                                     -0.063970
# Credit_History_Length                                 0.075613
# Outstanding_Loans                                     0.168306
# Loan_Amount                                          -0.021736
# Loan_Tenure_Months                                   -0.077960
# Savings_Account_Balance                               0.229542
# Checking_Account_Balance                             -0.001911
# Delinquency_12M                                      -0.068064
# Credit_Card_Utilization                               0.108283
# Behavior_Spending_Score                              -0.106748
# Behavior_Repayment_Score                             -0.091158
# No_of_Open_Accounts                                  -0.027201
# No_of_Closed_Accounts                                 0.183586
# Total_Credit_Limit                                    0.056457
# Total_Current_Balance                                -0.118184
# Credit_Utilization_Ratio                              0.054162
# No_of_Inquiries_6M                                   -0.009041
# No_of_Inquiries_12M                                  -0.001469
# DPD_30                                                0.097152
# DPD_60                                                0.067258
# DPD_90                                               -0.053729
# Worst_Current_Status                                  0.071907
# Months_Since_Most_Recent_Delinquency                  0.120653
# Max_Credit_Exposure                                   0.148370
# Oldest_Trade_Open_Months                              1.000000
# Newest_Trade_Open_Months                              0.105563
#
#                                       Newest_Trade_Open_Months
# Age                                                  -0.004094
# Income_INR                                            0.048253
# Employment_Years                                      0.152370
# Credit_History_Length                                -0.181577
# Outstanding_Loans                                    -0.112792
# Loan_Amount                                          -0.004060
# Loan_Tenure_Months                                    0.084881
# Savings_Account_Balance                               0.043400
# Checking_Account_Balance                             -0.153063
# Delinquency_12M                                      -0.001501
# Credit_Card_Utilization                               0.110136
# Behavior_Spending_Score                              -0.114922
# Behavior_Repayment_Score                             -0.035392
# No_of_Open_Accounts                                   0.108235
# No_of_Closed_Accounts                                -0.050332
# Total_Credit_Limit                                    0.047184
# Total_Current_Balance                                -0.125584
# Credit_Utilization_Ratio                              0.015136
# No_of_Inquiries_6M                                    0.091321
# No_of_Inquiries_12M                                   0.005791
# DPD_30                                               -0.024511
# DPD_60                                               -0.069006
# DPD_90                                               -0.067193
# Worst_Current_Status                                 -0.025285
# Months_Since_Most_Recent_Delinquency                  0.005426
# Max_Credit_Exposure                                  -0.113998
# Oldest_Trade_Open_Months                              0.105563
# Newest_Trade_Open_Months                              1.000000
#
# [28 rows x 28 columns]
#
# 📊 VIF Values:
#                                   Feature        VIF
# 0                                    Age  12.828451
# 26              Oldest_Trade_Open_Months   7.350703
# 17              Credit_Utilization_Ratio   7.093881
# 25                   Max_Credit_Exposure   6.691785
# 1                             Income_INR   6.538957
# 6                     Loan_Tenure_Months   5.962227
# 10               Credit_Card_Utilization   5.902522
# 12              Behavior_Repayment_Score   5.575830
# 24  Months_Since_Most_Recent_Delinquency   5.495815
# 27              Newest_Trade_Open_Months   5.341265
# 4                      Outstanding_Loans   5.332703
# 3                  Credit_History_Length   5.323027
# 14                 No_of_Closed_Accounts   5.241257
# 7                Savings_Account_Balance   5.162630
# 5                            Loan_Amount   5.095512
# 11               Behavior_Spending_Score   4.982186
# 19                   No_of_Inquiries_12M   4.935667
# 13                   No_of_Open_Accounts   4.928673
# 16                 Total_Current_Balance   4.906205
# 8               Checking_Account_Balance   4.886554
# 2                       Employment_Years   4.841223
# 18                    No_of_Inquiries_6M   4.772269
# 15                    Total_Credit_Limit   4.556445
# 9                        Delinquency_12M   3.876863
# 22                                DPD_90   3.226376
# 20                                DPD_30   2.780970
# 21                                DPD_60   2.572532
# 23                  Worst_Current_Status   2.061988

# %%
# -----------------------
# Step 6: Select final features
# -----------------------

# 1. Keep features with IV >= 0.02 (Weak or better)
selected_features = iv_summary[iv_summary["IV"] >= 0.02]["Variable"].tolist()

# 2. Drop features with too many missing values (>30% for example)
# missing_pct = (df[selected_features].isnull().mean() * 100)
# selected_features = [f for f in selected_features if missing_pct[f] <= 30]

# 3. Drop features with very high multicollinearity (VIF > 10)
# Recalculate VIF only on selected numeric variables
from statsmodels.stats.outliers_influence import variance_inflation_factor

numeric_selected = [f for f in selected_features if f in numeric_vars]
X_num = df[numeric_selected].dropna()

vif_data = pd.DataFrame()
vif_data["Feature"] = numeric_selected
vif_data["VIF"] = [variance_inflation_factor(X_num.values, i) 
                   for i in range(len(numeric_selected))]

# Drop high-VIF features
high_vif_features = vif_data[vif_data["VIF"] > 10]["Feature"].tolist()
selected_features = [f for f in selected_features if f not in high_vif_features]

# %%
# -----------------------
# Step 7: Final dataset
# -----------------------
final_df = df[selected_features + [target]].copy()

print("✅ Final Dataset Shape:", final_df.shape)
print("✅ Final Features:", selected_features)
print(final_df.head())
# Out:
# ✅ Final Dataset Shape: (100, 28)
# ✅ Final Features: ['Education_Level', 'Behavior_Spending_Score', 'Income_INR', 'Total_Credit_Limit', 'Loan_Tenure_Months', 'Months_Since_Most_Recent_Delinquency', 'Credit_Utilization_Ratio', 'Credit_Card_Utilization', 'Employment_Years', 'Behavior_Repayment_Score', 'No_of_Inquiries_6M', 'Credit_History_Length', 'Worst_Current_Status', 'No_of_Closed_Accounts', 'Newest_Trade_Open_Months', 'Checking_Account_Balance', 'Pay_History', 'No_of_Inquiries_12M', 'Delinquency_12M', 'Loan_Amount', 'Outstanding_Loans', 'Oldest_Trade_Open_Months', 'Total_Current_Balance', 'Max_Credit_Exposure', 'No_of_Open_Accounts', 'DPD_30', 'Savings_Account_Balance']
#   Education_Level  Behavior_Spending_Score  Income_INR  Total_Credit_Limit  \
# 0        Graduate                       73     2309818             1996830
# 1    Postgraduate                       26     2431785             2664150
# 2        Graduate                       66      488998             1618560
# 3     High School                       73     2043400              515757
# 4        Graduate                       73     1279111             2655214
#
#    Loan_Tenure_Months  Months_Since_Most_Recent_Delinquency  \
# 0                  48                                    56
# 1                  24                                     6
# 2                  72                                    21
# 3                  24                                    54
# 4                  24                                    32
#
#    Credit_Utilization_Ratio  Credit_Card_Utilization  Employment_Years  \
# 0                      0.15                     0.49                 0
# 1                      0.53                     0.41                 8
# 2                      0.25                     0.77                27
# 3                      0.48                     0.01                26
# 4                      0.39                     0.60                 5
#
#    Behavior_Repayment_Score  ...  Delinquency_12M  Loan_Amount  \
# 0                        13  ...                3       448929
# 1                        82  ...                0       630466
# 2                        33  ...                3       623695
# 3                        16  ...                0       513556
# 4                        42  ...                1       625278
#
#    Outstanding_Loans  Oldest_Trade_Open_Months  Total_Current_Balance  \
# 0                  9                       227                1523688
# 1                  6                       237                 171102
# 2                  9                       225                 395274
# 3                  4                       142                 218285
# 4                  2                        87                1387980
#
#    Max_Credit_Exposure No_of_Open_Accounts  DPD_30  Savings_Account_Balance  \
# 0               989211                   4       2                   813831
# 1              1626107                   1       0                   653465
# 2               697160                   3       0                   217454
# 3              1930947                   9       0                   999748
# 4               339972                   7       1                   110575
#
#    Default_y
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0
#
# [5 rows x 28 columns]

# %%
# -----------------------
# Step 8: Save Final Dataset
# -----------------------

# Define save path (adjust as needed)
save_path = r"C:\Users\rajat\OneDrive\Desktop\Inputs scorecard\EDA.xlsx"

# Save to Excel
final_df.to_excel(save_path, index=False)

print(f"✅ Final dataset saved successfully at: {save_path}")
# Out:
# ✅ Final dataset saved successfully at: C:\Users\rajat\OneDrive\Desktop\Inputs scorecard\EDA.xlsx

# %%
print("Total variables initially:", len(independent_vars))
print("After IV filtering:", len(iv_summary[iv_summary["IV"] >= 0.02]))
# Out:
# Total variables initially: 31
# After IV filtering: 28
